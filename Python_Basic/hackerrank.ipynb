# %% [markdown]
# Your lab is prototyping a Smart Light that turns on only when the room is bright enough. You are given two real numbers: the current brightness and a threshold. If brightness ≥ threshold, print ON; otherwise print OFF.
#
# Input Format
#
# One line with two real numbers:
#
# brightness threshold
# Constraints
#
# Use only input/output, arithmetic, and a single if/else
# No loops, no lists/arrays, no functions required
# Values fit within standard double precision
# Output Format
#
# Print exactly one word:
#
# ON
# if brightness ≥ threshold, else
#
# OFF
# Sample Input 0
#
# 60 50
# Sample Output 0
#
# ON
# Sample Input 1
#
# 40 50
# Sample Output 1
#
# OFF

# %%
user_input=input()
brightness,threshold=user_input.split()

if float(brightness)>=float(threshold):print("ON")
else:print("OFF")
# Out:
# OFF

# %% [markdown]
# You’re calibrating a tiny sensor before training a model. Given x, min_v, and max_v, compute:
#
# norm = (x - min_v) / (max_v - min_v)
# Then print norm with 2 decimal places.
#
# New concept — Feature scaling
#
# Models learn better when inputs share similar scales; min–max transform values into [0, 1] using a equation
#
# Input Format
#
# One line with three real numbers:
#
# x min_v max_v
# Constraints
#
# Assume max_v > min_v
# Basics only: input/output and arithmetic
# No lists/arrays; no loops required
# Output Format
#
# Print a single real number with 2 decimal places (e.g., 0.42).
#
# Sample Input 0
#
# 0 0 10
# Sample Output 0
#
# 0.00
# Sample Input 1
#
# 2.5 0 10
# Sample Output 1
#
# 0.25

# %%
user_input=input()
x,min_v,max_v=map(float,user_input.split())
norm=(x-min_v)/(max_v-min_v)
print(f"{norm:.2f}")

# %% [markdown]
# Your tiny trainer reports a stream of loss values. Read how many values to process, then read that many losses and compute the average. If the average loss is ≤ target, print PASS; otherwise print RETRY.
#
# Input Format
#
# First line: an integer N (how many losses) Second line: a real number target Next N lines: each a real number loss_i
#
# N
# target
# loss_1
# loss_2
# ...
# loss_N
# Constraints
#
# N ≥ 1
# Use only basics: input/output, arithmetic, and simple control flow
# No lists/arrays required
# Output Format
#
# Print exactly one word:
#
# PASS
# if average loss ≤ target, else
#
# RETRY
# Sample Input 0
#
# 3
# 0.35
# 0.20
# 0.30
# 0.40
# Sample Output 0
#
# PASS
# Sample Input 1
#
# 5
# 0.40
# 0.45
# 0.42
# 0.39
# 0.41
# 0.44
# Sample Output 1
#
# RETRY

# %%
N=eval(input())
target=eval(input())
if N>=1:
    total_loss=0
    for i in range(N):
        loss=eval(input())
        total_loss+=loss
    avg_loss=total_loss/N
    if target>=avg_loss:print("PASS")
    else:print("RETRY")
# Out:
# PASS

# %% [markdown]
# You’re simulating an ensemble of mini-models that each vote YES or NO on admitting a user. Read how many votes there are, then read each vote. If the number of YES votes is greater than or equal to the number of NO votes, print ACCEPT; otherwise print REJECT.
#
# New concept — Ensemble majority voting
#
# Several weak opinions can combine into one stronger decision.
#
# Input Format
#
# First line: integer N (number of votes) Next N lines: each is YES or NO (uppercase)
#
# N
# YES
# NO
# ...
# Constraints
#
# N ≥ 1
# Inputs are only YES or NO (uppercase)
# Basics only: input/output and simple conditions
# No lists/arrays required
# Output Format
#
# Print exactly one word:
#
# ACCEPT
# if YES_count ≥ NO_count, else
#
# REJECT
# Sample Input 0
#
# 1
# YES
# Sample Output 0
#
# ACCEPT
# Sample Input 1
#
# 1
# NO
# Sample Output 1
#
# REJECT

# %%
N=eval(input())
if N>=1:
    yes_count=0
    no_count=0
    for i in range(N):
        vote=input().upper()
        if vote=="YES":
            yes_count+=1
        elif vote=="NO":
            no_count+=1
    if yes_count>=no_count:
        print("ACCEPT")
    else:
        print("REJECT")
# Out:
# ACCEPT

# %% [markdown]
# In real AI systems, mood detection uses natural language processing (NLP) to understand emotions from text. For now, let's simulate a mini version of that!
#
# You are given a sentence that represents a user's message. Your job is to guess if the mood is happy, sad, or neutral using simple logic:
#
# If the message contains words like happy, joy, or smile, print Happy Mood.
# If it contains words like sad, cry, or angry, print Sad Mood.
# Otherwise, print Neutral Mood.
# Input Format
#
# A single string representing a user's message.
#
# Constraints
#
# The message will contain only lowercase English letters.
# Length of the message ≤ 100.
# Output Format
#
# Print one line: either Happy Mood, Sad Mood, or Neutral Mood.
#
# Sample Input 0
#
# happy birthday
# Sample Output 0
#
# Happy Mood
# Sample Input 1
#
# i am angry today
# Sample Output 1
#
# Sad Mood
# Sample Input 2
#
# just walking around
# Sample Output 2
#
# Neutral Mood

# %%
sentence=input().lower()
if "happy" in sentence or "joy" in sentence or "smile" in sentence:
    print("Happy Mood")
elif "sad" in sentence or  "cry" in sentence or "angry" in sentence:
    print("Sad Mood")
else:print("Neutral Mood")
# Out:
# Sad Mood

# %% [markdown]
# AI systems often analyze images by looking at the brightness of pixels. Each pixel has a brightness value, usually between 0 (dark) and 255 (bright). Let's simulate this concept!
#
# You are given a list of integers representing pixel brightness values. Your task is to find the average brightness and decide whether the image is Dark, Normal, or Bright.
#
# If the average brightness < 85 → print Dark Image
# If 85 ≤ average brightness ≤ 170 → print Normal Image
# If average brightness > 170 → print Bright Image
# Input Format
#
# A list of integers separated by spaces.
#
# Constraints
#
# 1 ≤ number of pixels ≤ 100
# 0 ≤ pixel value ≤ 255
# Output Format
#
# Print one line: Dark Image, Normal Image, or Bright Image.
#
# Sample Input 0
#
# 10 20 30 40
# Sample Output 0
#
# Dark Image
# Sample Input 1
#
# 100 150 120 90
# Sample Output 1
#
# Normal Image
# Sample Input 2
#
# 200 230 255 180
# Sample Output 2
#
# Bright Image

# %%
brightness_values=input().split()
sum=0
for i in brightness_values:
    sum+=int(i)
avg=sum/len(brightness_values)

if avg>170:print("Bright Image")
elif 85<=avg<=170:print("Normal Image")
elif avg<85:print("Dark Image")

# %% [markdown]
# In AI, bias means the model might favor one category more than others. Let’s simulate this idea with lists and conditional logic!
#
# You are given a list of predictions made by an AI model. Each prediction is either 'A' or 'B'.
#
# Your task is to check whether the model is biased or fair:
#
# If the count of 'A' or 'B' is more than 70% of all predictions, print Biased Model.
# Otherwise, print Fair Model.
# Input Format
#
# A list of uppercase letters (A or B) separated by spaces.
#
# Constraints
#
# 1 ≤ number of predictions ≤ 100
# Each prediction is either A or B
# Output Format
#
# Print one line: either Biased Model or Fair Model.
#
# Sample Input 0
#
# A A A B B A A
# Sample Output 0
#
# Biased Model
# Sample Input 1
#
# A B A B A B
# Sample Output 1
#
# Fair Model

# %%
pred=input().split()
a_count=0
b_count=0
for i in pred:
    if i.upper()=="A":
        a_count+=1
    elif i.upper()=="B":
        b_count+=1
a=(a_count/len(pred))*100
b=(b_count/len(pred))*100
if a>70 or b>70:print("Biased Model")
else:print("Fair Model")

# %% [markdown]
# AI systems often scan user messages to find keywords and understand intent. Let’s build a simple version of that!
#
# You are given a user's message and a list of AI-related keywords. Your task is to count how many of those keywords appear in the message.
#
# The keywords to look for are:
#
# ai, data, model, learn, train, neural
#
# If 2 or more keywords are found, print AI Detected. Otherwise, print Not AI Related.
#
# Input Format
#
# A single line of text (the user's message).
#
# Constraints
#
# The message will contain only lowercase English letters and spaces.
# Message length ≤ 200.
# Output Format
#
# Print one line: either AI Detected or Not AI Related.
#
# Sample Input 0
#
# i love to train a neural model
# Sample Output 0
#
# AI Detected
# Sample Input 1
#
# i like reading books
# Sample Output 1
#
# Not AI Related

# %%
sentence=input().split()
count=0
for i in sentence:
    if i=="ai" or i=="data" or i=="model" or i=="learn" or i=="train" or i=="neural":count+=1
if count>=2:print("AI Detected")
else:print("Not AI Related")
